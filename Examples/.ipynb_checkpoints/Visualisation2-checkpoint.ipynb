# %%
import joblib
import sys
sys.path.insert(0,'/Users/walfits/Repositories/Aglaia/')
import energies_NN as nn
import numpy as np
from sklearn import model_selection as modsel

# %%
# Loading the data
data = joblib.load("cc_demeaned_kjmol.bz")
X = data["X"]
y = np.reshape(data["y"], (data["y"].shape[0],))

print(X.shape, y.shape)
# Out:
# (20698, 28) (20698,)

# %%
# Splitting the data
X_train, X_test, y_train, y_test = modsel.train_test_split(X, y, test_size=0.2)
print(X_train.shape)
# Out:
# (16558, 28)

# %%
# Training the model
estimator = nn.Energies_NN(max_iter=4000, learning_rate_init=0.005, hidden_layer_sizes=(13,), batch_size=1000,
                              alpha=0.0005, tensorboard=False)

# %%
estimator.fit(X_train, y_train)

# %%
random_input = abs(np.random.rand(28))
alpha_l1 = [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1]

# %%
all_data = []
for al in alpha_l1:
    estimator.optimise_input(random_input, al, 0)
    all_data.append(estimator.final_x_tot)
# Out:
# The activations at the end of the optimisations are:
# [array([[ 0.99999607]], dtype=float32), array([[ 0.99999857]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 0.99999809]], dtype=float32), array([[ 0.99999082]], dtype=float32), array([[ 0.99999809]], dtype=float32), array([[ 0.99999881]], dtype=float32), array([[ 0.99999344]], dtype=float32), array([[ 0.99999976]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 0.9999969]], dtype=float32), array([[ 0.99999881]], dtype=float32), array([[ 0.99999893]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99999022]], dtype=float32), array([[ 0.99999714]], dtype=float32), array([[ 0.99999964]], dtype=float32), array([[ 0.9999944]], dtype=float32), array([[ 0.99998474]], dtype=float32), array([[ 0.99999428]], dtype=float32), array([[ 0.99999821]], dtype=float32), array([[ 0.99998665]], dtype=float32), array([[ 0.99999964]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 0.99999595]], dtype=float32), array([[ 0.99999654]], dtype=float32), array([[ 0.99999857]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99994731]], dtype=float32), array([[ 0.99997354]], dtype=float32), array([[ 0.99999619]], dtype=float32), array([[ 0.9999733]], dtype=float32), array([[ 0.99993217]], dtype=float32), array([[ 0.99997306]], dtype=float32), array([[ 0.99999726]], dtype=float32), array([[ 0.99996364]], dtype=float32), array([[ 0.9999907]], dtype=float32), array([[ 0.99998009]], dtype=float32), array([[ 0.99993396]], dtype=float32), array([[ 0.99997413]], dtype=float32), array([[ 0.99997818]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99961179]], dtype=float32), array([[ 0.99980634]], dtype=float32), array([[ 0.9999584]], dtype=float32), array([[ 0.9998647]], dtype=float32), array([[ 0.99951291]], dtype=float32), array([[ 0.99978095]], dtype=float32), array([[ 0.99983048]], dtype=float32), array([[ 0.99969625]], dtype=float32), array([[ 0.99991572]], dtype=float32), array([[ 0.99982762]], dtype=float32), array([[ 0.99944538]], dtype=float32), array([[ 0.99983871]], dtype=float32), array([[ 0.99979788]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99647981]], dtype=float32), array([[ 0.99826837]], dtype=float32), array([[ 0.99948466]], dtype=float32), array([[ 0.99865675]], dtype=float32), array([[ 0.99531132]], dtype=float32), array([[ 0.99799263]], dtype=float32), array([[ 0.99842703]], dtype=float32), array([[ 0.99742508]], dtype=float32), array([[ 0.99917501]], dtype=float32), array([[ 0.99842298]], dtype=float32), array([[ 0.99470913]], dtype=float32), array([[ 0.99847883]], dtype=float32), array([[ 0.99816847]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.96166855]], dtype=float32), array([[ 0.98229295]], dtype=float32), array([[ 0.9952265]], dtype=float32), array([[ 0.98613864]], dtype=float32), array([[ 0.9511053]], dtype=float32), array([[ 0.97918802]], dtype=float32), array([[ 0.98341644]], dtype=float32), array([[ 0.97285604]], dtype=float32), array([[ 0.990906]], dtype=float32), array([[ 0.98396701]], dtype=float32), array([[ 0.94332188]], dtype=float32), array([[ 0.98442233]], dtype=float32), array([[ 0.98146158]], dtype=float32)]

# %%
alpha_l1_more = [0.0000001, 0.0000005, 0.00005, 0.0005, 0.005, 0.05, 0.5, 1]
for al in alpha_l1_more:
    estimator.optimise_input(random_input, al, 0)
    all_data.append(estimator.final_x_tot)
# Out:
# The activations at the end of the optimisations are:
# [array([[ 0.99999702]], dtype=float32), array([[ 0.99999917]], dtype=float32), array([[ 1.]], dtype=float32), array([[ 0.99999869]], dtype=float32), array([[ 0.99999273]], dtype=float32), array([[ 0.99999869]], dtype=float32), array([[ 0.99999881]], dtype=float32), array([[ 0.9999944]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 1.]], dtype=float32), array([[ 0.9999969]], dtype=float32), array([[ 0.99999928]], dtype=float32), array([[ 0.99999893]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99999642]], dtype=float32), array([[ 0.99999869]], dtype=float32), array([[ 1.]], dtype=float32), array([[ 0.99999833]], dtype=float32), array([[ 0.9999913]], dtype=float32), array([[ 0.99999833]], dtype=float32), array([[ 0.99999881]], dtype=float32), array([[ 0.9999938]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 0.99999988]], dtype=float32), array([[ 0.9999969]], dtype=float32), array([[ 0.99999893]], dtype=float32), array([[ 0.99999893]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99996161]], dtype=float32), array([[ 0.99998677]], dtype=float32), array([[ 0.99999762]], dtype=float32), array([[ 0.9999845]], dtype=float32), array([[ 0.99995959]], dtype=float32), array([[ 0.99998152]], dtype=float32), array([[ 0.99999869]], dtype=float32), array([[ 0.99997282]], dtype=float32), array([[ 0.99999309]], dtype=float32), array([[ 0.99999619]], dtype=float32), array([[ 0.99997485]], dtype=float32), array([[ 0.99998462]], dtype=float32), array([[ 0.99999475]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99978787]], dtype=float32), array([[ 0.99989593]], dtype=float32), array([[ 0.99998093]], dtype=float32), array([[ 0.99990809]], dtype=float32), array([[ 0.99972123]], dtype=float32), array([[ 0.99988234]], dtype=float32), array([[ 0.99991488]], dtype=float32), array([[ 0.99983156]], dtype=float32), array([[ 0.99995756]], dtype=float32), array([[ 0.99990177]], dtype=float32), array([[ 0.99971229]], dtype=float32), array([[ 0.99990571]], dtype=float32), array([[ 0.99989653]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.99824643]], dtype=float32), array([[ 0.999138]], dtype=float32), array([[ 0.99978501]], dtype=float32), array([[ 0.99932182]], dtype=float32), array([[ 0.9975515]], dtype=float32), array([[ 0.99900335]], dtype=float32), array([[ 0.99919027]], dtype=float32), array([[ 0.9986971]], dtype=float32), array([[ 0.99956745]], dtype=float32), array([[ 0.99924785]], dtype=float32), array([[ 0.99731147]], dtype=float32), array([[ 0.9992556]], dtype=float32), array([[ 0.99901438]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.98141128]], dtype=float32), array([[ 0.99147838]], dtype=float32), array([[ 0.99764556]], dtype=float32), array([[ 0.99319118]], dtype=float32), array([[ 0.97601819]], dtype=float32), array([[ 0.99017429]], dtype=float32), array([[ 0.99178231]], dtype=float32), array([[ 0.9863804]], dtype=float32), array([[ 0.99579167]], dtype=float32), array([[ 0.99213421]], dtype=float32), array([[ 0.97271812]], dtype=float32), array([[ 0.99248523]], dtype=float32), array([[ 0.99041069]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.77023697]], dtype=float32), array([[ 0.90368134]], dtype=float32), array([[ 0.97305661]], dtype=float32), array([[ 0.92894775]], dtype=float32), array([[ 0.62862349]], dtype=float32), array([[ 0.88827527]], dtype=float32), array([[ 0.90626907]], dtype=float32), array([[ 0.84973699]], dtype=float32), array([[ 0.9544673]], dtype=float32), array([[ 0.91946566]], dtype=float32), array([[ 0.42838755]], dtype=float32), array([[ 0.9201197]], dtype=float32), array([[ 0.89295578]], dtype=float32)]
# The activations at the end of the optimisations are:
# [array([[ 0.65733868]], dtype=float32), array([[ 0.78033626]], dtype=float32), array([[ 0.94877809]], dtype=float32), array([[ 0.84373677]], dtype=float32), array([[ 0.40584624]], dtype=float32), array([[ 0.73979467]], dtype=float32), array([[ 0.79266161]], dtype=float32), array([[ 0.56782991]], dtype=float32), array([[ 0.90372598]], dtype=float32), array([[ 0.8092497]], dtype=float32), array([[ 0.42213196]], dtype=float32), array([[ 0.82106167]], dtype=float32), array([[ 0.74605638]], dtype=float32)]

# %%
print(len(all_data))
print(len(all_data[0]))
print(len(all_data[0][0]))
# Out:
# 14
# 13
# 28

# %%
alpha_l1_extend = alpha_l1 + alpha_l1_more

# %%
import pandas as pd
import seaborn as sns

df = pd.DataFrame()
df["log_alpha"]=-np.log(alpha_l1_extend)
features = []

for i in range(len(all_data[0][0])): # 0-27
    fi = []
    for j in range(len(all_data)):   # 0-5
        fi.append(all_data[j][0][i])
    features.append(fi)
    
print(len(features))
print(len(features[0]))
# Out:
# 28
# 14

# %%
cols = ["C1", "C1H1", "C1H2", "C1H3", "C1H4", "C1C2", "C1N", "H1", "H1H2", "H1H3", "H1H4", "H1C2", "H1N", "H2", "H2H3", "H2H4", "H2C2", "H2N", "H3", "H3H4", "H3C2", "H3N", "H4", "H4C2", "H4N", "C2", "C2N", "N"]
for i in range(len(features)):
    name = cols[i]
    df[name] = features[i]

df.head()
# Out:
#    log_alpha        C1      C1H1      C1H2      C1H3      C1H4      C1C2  \
# 0  13.815511  0.410967  0.801137  0.000000  0.019577  0.550459  0.000000
# 1  11.512925  0.295606  0.492232  0.000003  0.000002  0.522493  0.000274
# 2   9.210340  0.000025  0.000344  0.000000  0.000197  0.242799  0.000000
# 3   6.907755  0.001051  0.000000  0.000000  0.001830  0.000000  0.000000
# 4   4.605170  0.000142  0.001710  0.000000  0.000000  0.000527  0.000000
#
#         C1N        H1     H1H2    ...           H3      H3H4      H3C2  \
# 0  0.000000  0.877626  0.00000    ...     0.957183  0.000000  0.559389
# 1  0.000000  0.734055  0.00000    ...     0.807845  0.000000  0.580601
# 2  0.000000  0.000000  0.00000    ...     0.000000  0.000011  0.829889
# 3  0.000000  0.000000  0.00000    ...     0.000000  0.000000  0.823139
# 4  0.000648  0.001638  0.00084    ...     0.000000  0.000000  0.010379
#
#         H3N        H4      H4C2      H4N        C2      C2N         N
# 0  0.965747  0.617704  0.646722  0.00000  0.521672  0.00000  0.732834
# 1  0.934695  0.472961  0.645441  0.00016  0.425559  0.00000  0.588446
# 2  0.944028  0.000000  0.937278  0.00000  0.000102  0.00004  0.000153
# 3  0.000188  0.000488  1.358894  0.00000  0.002254  0.00000  0.000977
# 4  0.000607  0.000000  1.772181  0.00000  0.001386  0.00000  0.000582
#
# [5 rows x 29 columns]

# %%
df_melt = df.melt('log_alpha', var_name='cols',  value_name='vals')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sns.set_style("darkgrid", {'axes.grid' : False})
sns.set_context("paper", font_scale=1.2 , rc={"lines.linewidth": 1})

fig, ax = plt.subplots()
fig.set_size_inches(15, 9)


markers = ['x','x','x','x','x','x','x','x','x', 'o','o','o','o','o','o','o','o','o','v','v','v','v','v','v','v','v','v','<']
line_style = ["-","-","-","-","-","-","-","-","-",":",":",":",":",":",":",":",":",":","--","--","--","--","--","--","--","--","--","--"]
the_plot = sns.factorplot(x="log_alpha", y="vals", hue='cols', data=df_melt, ax=ax, palette=sns.color_palette("Set1", desat=0.5),  markers=markers)
ax.set(xlabel='-log(alpha)', ylabel='value of input features')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))


plt.show()

# %%
df.to_csv("l1_scan.csv")
