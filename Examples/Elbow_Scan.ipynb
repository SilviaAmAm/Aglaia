# %% [markdown]
# This notebook plots the R2 as a function of number of hidden neurons obtained in the hyper parameter optimisation of osprey.

# %%
n_nodes = range(1,21)
# scores = [0.750710, 0.799943, 0.893002, 0.908559, 0.917713, 0.926704, 0.936887, 0.940034, 0.942339, 0.942667, 0.949883, 0.949472, 0.951866, 0.955097, 0.955206, 0.957696, 0.959044, 0.960529, 0.961550, 0.963862]
# scores = [0.750722, 0.795933, 0.864712, 0.906034, 0.917711, 0.925420, 0.935214, 0.934432, 0.943050, 0.942770, 0.946661,0.952366, 0.949023, 0.955937, 0.956068, 0.956734, 0.960160, 0.948533, 0.962041,0.962424]
scores = [0.750571, 0.799948, 0.903061, 0.903418, 0.917711, 0.916042, 0.926229, 0.934591, 0.942593, 0.942391, 0.946661,0.952366, 0.949023, 0.955937, 0.956068, 0.956734, 0.960160, 0.948533, 0.962041,0.962424]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()
plt.plot()
plt.plot(n_nodes, scores, 'o-')
plt.ylabel('R2 score')
plt.xlabel('Number of nodes')
plt.xticks(n_nodes)
plt.show()
